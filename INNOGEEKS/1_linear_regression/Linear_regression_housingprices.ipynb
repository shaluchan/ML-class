# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import linear_model
# %matplotlib inline

# %%
df= pd.read_csv('housing_price_dataset.csv')
df
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [50000 rows x 6 columns]

# %%
df.drop(columns=["Bedrooms"],inplace=True)
df.drop(columns=["Bathrooms"],inplace=True)
df.drop(columns=["Neighborhood"],inplace=True)
df.drop(columns=["YearBuilt"],inplace=True)

# %%
df
# Out:
#        SquareFeet          Price
# 0            2126  215355.283618
# 1            2459  195014.221626
# 2            1860  306891.012076
# 3            2294  206786.787153
# 4            2130  272436.239065
# ...           ...            ...
# 49995        1282  100080.865895
# 49996        2854  374507.656727
# 49997        2979  384110.555590
# 49998        2596  380512.685957
# 49999        1572  221618.583218
#
# [50000 rows x 2 columns]

# %%
plt.xlabel('SquareFeet')
plt.ylabel('Price')
plt.scatter(df.SquareFeet,df.Price,color='yellow',marker='+')

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['SquareFeet']],df.Price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /usr/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([353312.91828091])

# %%
reg.coef_
# Out:
# array([99.32210752])

# %%
reg.intercept_
# Out:
# 25549.96344887439

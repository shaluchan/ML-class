# %%
for i in range(0,5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i=5
while i>0:
    print(i*"*")
    i-=1
# Out:
# *****
# ****
# ***
# **
# *

# %%
students =['shalu','kasak','anshika','nikhil']
for student in students:
    if student=='anshika':
        continue;
    print(student)
# Out:
# shalu
# kasak
# nikhil

# %%
#while loop
#for loop
number=int(input("enter the number"))
i=1
while i<11:
    print(number,"*",i,"=",number*i)
    i+=1
# Out:
# enter the number 4
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40

# %%
for i in range(1,11,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in "kolkata":
    print(i)
# Out:
# k
# o
# l
# k
# a
# t
# a

# %%
for i in {1,2,3,4,5}:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#agr pta h loop kitni baar chlega  , then use for  loop
#agr nhi pta loop kitni  baar chlega , then use while loop until condition satisfied.

# %%
rows=int(input("enter the number of rows"))
for i in range(1,rows+1):
    for j in range(0,i):
        print("*",end=" ")
    print("")
# Out:
# enter the number of rows 89
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *
# * * * * * * * *
# * * * * * * * * *
# * * * * * * * * * *
# * * * * * * * * * * *
# * * * * * * * * * * * *
# * * * * * * * * * * * * *
# * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# * * * * * * * * * * * * * * * * * * * * * * * * * * * * *
# ...

# %%
for i in range(1,11):
    if i==5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for  i in range(0,11):
    if i==7:
        continue
    print(i)
    print("hello")
# Out:
# 0
# hello
# 1
# hello
# 2
# hello
# 3
# hello
# 4
# hello
# 5
# hello
# 6
# hello
# 8
# hello
# 9
# hello
# 10
# hello

# %%
for i in range(1,11):
    pass#jha p unsure h ki abhi yha  kya code likhe to pass statemenet deke aage bdh skte h then baad m aake code likh skte h.isse  koi error nhi  ayega
